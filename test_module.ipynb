# %%
import importlib
import extract_fin_tab_pdf as eftp
importlib.reload(eftp)
import os

# %%
pdf_path=f"{os.getcwd()}/data/discover_10K_2021.pdf"

# %%
TabReadServ=eftp.FinTabPdf(path_pdf=pdf_path,page=56)

# %%
TabReadServ.preprocess_raw()
# Out:
#                                     row_nm    2021  Unnamed: 2    2020  \
# 2                        credit_card_loans   8,717         NaN   8,985
# 3                    private_student_loans     742         NaN     754
# 4                           personal_loans     878         NaN     958
# 5                              other_loans     114         NaN     106
# 6                    other_interest_income     200         NaN     292
# 7                    total_interest_income  10,651         NaN  11,095
# 8                         interest_expense   1,134         NaN   1,865
# 9                      net_interest_income   9,517         NaN   9,230
# 10             provision_for_credit_losses     218         NaN   5,134
# 11                            other_income   1,781         NaN   1,459
# 12                           other_expense   4,549         NaN   4,292
# 13        income_before_income_tax_expense   6,531         NaN   1,263
# ...

# %%
TabReadServ.title_rows
# Out:
# 0      digital_banking
# 1      interest_income
# 14    payment_services
# Name: row_nm, dtype: object

# %%
TabReadServ.units
# Out:
# {'2021': '$', '2020': '$', '2019': '$'}
