# %% [markdown]
# # Import Packages

# %%
import tabula
from re import sub
import pandas as pd
import numpy as np
import os

# %%
import extract as ex

# %% [markdown]
# # Import Data

# %%
dict_pos = {'Loan receivables, including held for sale': {'name': 'average_loan_receivables',
                                                          'uom': '$_mill',
                                                          'period': 'average'},
            'Total assets': {'name': 'average_assets', 'uom': '$_mill', 'period': 'average'},
            'Deposits': {'name': 'average_deposits', 'uom': '$_mill', 'period': 'average'},
            'Borrowings': {'name': 'average_corporate_loans', 'uom': '$_mill', 'period': 'average'},
            'Total equity': {'name': 'average_equity', 'uom': '$_mill', 'period': 'average'},
            'Purchase volume': {'name': 'net_credit_sales', 'uom': '$_mill', 'period': 'end'},
            'Retail Card': {'name': 'net_credit_sales_retail_card',
                            'uom': '$_mill',
                            'period': 'end'},
            'Payment Solutions': {'name': 'net_credit_sales_payment_solutions',
                                  'uom': '$_mill',
                                  'period': 'end'},
            'CareCredit': {'name': 'net_credit_sales_care_credit',
                           'uom': '$_mill',
                           'period': 'end'},
            'Home & Auto': {'name': 'net_credit_sales_home_auto',
                            'uom': '$_mill',
                            'period': 'end'},
            'Digital': {'name': 'net_credit_sales_digital', 'uom': '$_mill', 'period': 'end'},
            'Diversified & Value': {'name': 'net_credit_sales_diversified_value',
                                    'uom': '$_mill',
                                    'period': 'end'},
            'Health & Wellness': {'name': 'net_credit_sales_health_wellness',
                                  'uom': '$_mill',
                                  'period': 'end'},
            'Lifestyle': {'name': 'net_credit_sales_lifestyle', 'uom': '$_mill', 'period': 'end'},
            'Corp, Other': {'name': 'net_credit_sales_corp_other',
                            'uom': '$_mill',
                            'period': 'end'},
            'Average active accounts': {'name': 'average_active_accounts',
                                        'uom': 'thousands',
                                        'period': 'average'},
            'Net interest margin': {'name': 'net_interest_income_to_average_interest_earning_assets',
                                    'uom': 'perc',
                                    'period': 'average'},
            'Net charge-offs': {'name': 'net_charge_offs', 'uom': '$_mill', 'period': 'end'},
            'Net charge-offs as a % of average loan receivables, including held for sale': {'name': 'net_charge_offs_to_average_loan_receivables',
                                                                                            'uom': 'perc',
                                                                                            'period': 'average'},
            'Allowance coverage ratio': {'name': 'allowance_for_loan_losses_to_loan_receivables',
                                         'uom': 'perc',
                                         'period': 'end'},
            'Return on assets': {'name': 'return_on_average_assets',
                                 'uom': 'perc',
                                 'period': 'average'},
            'Return on equity': {'name': 'return_on_average_equity',
                                 'uom': 'perc',
                                 'period': 'average'},
            'Equity to assets': {'name': 'average_equity_to_average_assets',
                                 'uom': 'perc',
                                 'period': 'average'},
            'Other expense as a % of average loan receivables, including held for sale': {'name': 'other_expense_to_average_loan_receivables',
                                                                                          'uom': 'perc',
                                                                                          'period': 'average'},
            'Efficiency ratio': {'name': 'efficiency_ratio', 'uom': 'perc', 'period': 'end'},
            'Effective income tax rate': {'name': 'effective_income_tax_rate',
                                          'uom': 'perc',
                                          'period': 'end'},
            'Loan receivables': {'name': 'loan_receivables', 'uom': '$_mill', 'period': 'end'},
            'Allowance for credit losses': {'name': 'allowance_for_credit_losses',
                                            'uom': '$_mill',
                                            'period': 'end'},
            'Allowance for loan losses': {'name': 'allowance_for_credit_losses',
                                          'uom': '$_mill',
                                          'period': 'end'},
            '30+ days past due as a % of period-end loan receivables': {'name': '30_days_past_due_to_loan_receivables',
                                                                        'uom': '$_mill',
                                                                        'period': 'end'},
            '90+ days past due as a % of period-end loan receivables': {'name': '90_days_past_due_to_loan_receivables',
                                                                        'uom': '$_mill',
                                                                        'period': 'end'},
            'Total active accounts': {'name': 'active_accounts', 'uom': 'thousands', 'period': 'end'}}

# %%
pages={"2022":34,"2021":33,"2020":32,"2019":31,"2018":35,"2017":82,"2016":81}

# %%
dict_uom={_val["name"]:_val["uom"] for _val in dict_pos.values()}
dict_period={_val["name"]:_val["period"] for _val in dict_pos.values()}

# %%
results=[]
for year_current in ["2022","2021","2020","2019","2018","2017","2016"]:
    pdf_path=f"{os.getcwd()}/data/synchrony/synchrony_10K_{year_current}.pdf"
    pdf_data=tabula.read_pdf(pdf_path, pages=pages[year_current])[0]
    years=[str(int(year_current)-_year_add) for _year_add in range(3)]
    df=pdf_data.drop(columns=["Unnamed: 0","Unnamed: 2","Unnamed: 4" ])
    df=df.dropna()
    col_year=["Unnamed: 1","Unnamed: 3","Unnamed: 5"]
    year_mapping={_col:_year for _col,_year in zip(col_year,years)}
    df=df.rename(columns={"Financial Position Data (Average):":"position",**year_mapping})
    df["position"]=df["position"].apply(lambda x: x.split("(")[0])
    df["position"]=df["position"].apply(lambda x: x.strip())
    df["position"]=df["position"].replace({_key:_val["name"] for _key, _val in dict_pos.items()})
    for _col in df.columns:
        if _col!="position":
            df[_col]=df[_col].apply(lambda x: "".join(x.split(",")))
            df[_col]=df[_col].apply(lambda x:x.split(" ")[0])
            df[_col]=df[_col].apply(lambda x: x.replace('%', ''))
            df[_col]=df[_col].apply(lambda x: x.strip())
            df[_col]=df[_col].apply(float)
    df_pos_val=pd.melt(df, id_vars=['position'], value_vars=years,
            var_name='year', value_name='value')
    df_pos_val["fy"]=year_current
    df_pos_val["uom"]=df_pos_val["position"].apply(lambda x: dict_uom[x])
    df_pos_val["period"]=df_pos_val["position"].apply(lambda x: dict_period[x])
    results.append(df_pos_val)

# %%
df_result=pd.concat(results)

# %%
df_result
# Out:
#                                 position  year     value    fy        uom
# 0               average_loan_receivables  2022  84672.00  2022     $_mill  \
# 1                         average_assets  2022  98152.00  2022     $_mill
# 2                       average_deposits  2022  66006.00  2022     $_mill
# 3                average_corporate_loans  2022  13783.00  2022     $_mill
# 4                         average_equity  2022  13372.00  2022     $_mill
# ..                                   ...   ...       ...   ...        ...
# 70                      loan_receivables  2014  61286.00  2016     $_mill
# 71           allowance_for_credit_losses  2014   3236.00  2016     $_mill
# 72  30_days_past_due_to_loan_receivables  2014      4.14  2016     $_mill
# 73  90_days_past_due_to_loan_receivables  2014      1.90  2016     $_mill
# 74                       active_accounts  2014  64286.00  2016  thousands
#
#      period
# 0   average
# 1   average
# 2   average
# 3   average
# 4   average
# ..      ...
# 70      end
# 71      end
# 72      end
# 73      end
# 74      end
#
# [543 rows x 6 columns]

# %%
df_result.query("position== 'average_loan_receivables'")
# Out:
#                     position  year    value    fy     uom   period
# 0   average_loan_receivables  2022  84672.0  2022  $_mill  average
# 28  average_loan_receivables  2021  78928.0  2022  $_mill  average
# 56  average_loan_receivables  2020  80138.0  2022  $_mill  average
# 0   average_loan_receivables  2021  78928.0  2021  $_mill  average
# 28  average_loan_receivables  2020  80138.0  2021  $_mill  average
# 56  average_loan_receivables  2019  88649.0  2021  $_mill  average
# 0   average_loan_receivables  2020  80138.0  2020  $_mill  average
# 25  average_loan_receivables  2019  88649.0  2020  $_mill  average
# 50  average_loan_receivables  2018  83304.0  2020  $_mill  average
# 0   average_loan_receivables  2019  88649.0  2019  $_mill  average
# 25  average_loan_receivables  2018  83304.0  2019  $_mill  average
# 50  average_loan_receivables  2017  75702.0  2019  $_mill  average
# 0   average_loan_receivables  2018  83304.0  2018  $_mill  average
# 25  average_loan_receivables  2017  75702.0  2018  $_mill  average
# 50  average_loan_receivables  2016  68649.0  2018  $_mill  average
# 0   average_loan_receivables  2017  75702.0  2017  $_mill  average
# 25  average_loan_receivables  2016  68649.0  2017  $_mill  average
# 50  average_loan_receivables  2015  61655.0  2017  $_mill  average
# 0   average_loan_receivables  2016  68649.0  2016  $_mill  average
# 25  average_loan_receivables  2015  61655.0  2016  $_mill  average
# 50  average_loan_receivables  2014  57101.0  2016  $_mill  average

# %% [markdown]
# # PDF check

# %%
import PyPDF2

# %%
reader = PyPDF2.PdfReader(pdf_path)

# %% [markdown]
# # Average Balance

# %%
pdf_path=f"{os.getcwd()}/data/synchrony/synchrony_10K_{2021}.pdf"

# %%
tables = tabula.read_pdf_with_template(input_path = pdf_path, template_path = f"{os.getcwd()}/data/json/synchrony_10K_2021.json")

# %%
tables[0]
# Out:
#                                 Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                                      NaN        NaN        NaN        NaN  \
# 1                  Years ended December 31        NaN    Average        NaN
# 2                          ($ in millions)        NaN    Balance        NaN
# 3                                   Assets        NaN        NaN        NaN
# 4                 Interest-earning assets:        NaN        NaN        NaN
# 5                Interest-earning cash and        NaN        NaN        NaN
# 6                           equivalents(2)          $     11,673          $
# 7            Securities available for sale        NaN      5,975        NaN
# 8     Loan receivables, including held for        NaN        NaN        NaN
# 9                                 sale(3):        NaN        NaN        NaN
# 10                            Credit cards        NaN     75,052        NaN
# 11              Consumer installment loans        NaN      2,460        NaN
# 12              Commercial credit products        NaN      1,359        NaN
# 13                                   Other        NaN         57        NaN
# 14       Total loan receivables, including        NaN        NaN        NaN
# 15                           held for sale        NaN     78,928        NaN
# 16           Total interest-earning assets        NaN     96,576        NaN
# 17            Non-interest-earning assets:        NaN        NaN        NaN
# 18                 Cash and due from banks        NaN      1,597        NaN
# 19             Allowance for credit losses        NaN    (9,402)        NaN
# 20                            Other assets        NaN      5,343        NaN
# 21       Total non-interest-earning assets        NaN    (2,462)        NaN
# 22                            Total assets          $     94,114        NaN
# 23                             Liabilities        NaN        NaN        NaN
# 24           Interest-bearing liabilities:        NaN        NaN        NaN
# 25       Interest-bearing deposit accounts          $     60,953          $
# 26              Borrowings of consolidated        NaN        NaN        NaN
# 27                 securitization entities        NaN      7,248        NaN
# 28                  Senior unsecured notes        NaN      7,173        NaN
# 29      Total interest-bearing liabilities        NaN     75,374        NaN
# 30       Non-interest-bearing liabilities:        NaN        NaN        NaN
# 31   Non-interest-bearing deposit accounts        NaN        349        NaN
# 32                       Other liabilities        NaN      4,668        NaN
# 33  Total non-interest-bearing liabilities        NaN      5,017        NaN
# 34                       Total liabilities        NaN     80,391        NaN
# 35                                  Equity        NaN        NaN        NaN
# 36                            Total equity        NaN     13,723        NaN
# 37            Total liabilities and equity          $     94,114        NaN
# 38                 Interest rate spread(4)        NaN        NaN        NaN
# 39                     Net interest income        NaN        NaN          $
# 40                  Net interest margin(5)        NaN        NaN        NaN
#
#         2021 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7      2020 Unnamed: 8
# 0   Interest    Average        NaN        NaN        NaN  Interest    Average  \
# 1   Income /    Yield /        NaN    Average        NaN   Income/    Yield /
# 2    Expense    Rate(1)        NaN    Balance        NaN   Expense    Rate(1)
# 3        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 5        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 6         15     0.13 %          $     13,301          $        53     0.40 %
# 7         28     0.47 %        NaN      7,367        NaN        64     0.87 %
# 8        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 9        NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 10    14,880    19.83 %        NaN     77,115        NaN    15,672    20.32 %
# 11       241     9.80 %        NaN      1,733        NaN       168     9.69 %
# 12       103     7.58 %        NaN      1,231        NaN       108     8.77 %
# 13         4     7.02 %        NaN         59        NaN         2     3.39 %
# 14       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 15    15,228    19.29 %        NaN     80,138        NaN    15,950    19.90 %
# 16    15,271    15.81 %        NaN    100,806        NaN    16,067    15.94 %
# 17       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 18       NaN        NaN        NaN      1,488        NaN       NaN        NaN
# 19       NaN        NaN        NaN    (9,488)        NaN       NaN        NaN
# 20       NaN        NaN        NaN      4,932        NaN       NaN        NaN
# 21       NaN        NaN        NaN    (3,068)        NaN       NaN        NaN
# 22       NaN        NaN          $     97,738        NaN       NaN        NaN
# 23       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 24       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 25       566     0.93 %          $     63,755          $     1,094     1.72 %
# 26       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 27       169     2.33 %        NaN      8,675        NaN       237     2.73 %
# 28       297     4.14 %        NaN      8,171        NaN       334     4.09 %
# 29     1,032     1.37 %        NaN     80,601        NaN     1,665     2.07 %
# 30       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 31       NaN        NaN        NaN        306        NaN       NaN        NaN
# 32       NaN        NaN        NaN      4,498        NaN       NaN        NaN
# 33       NaN        NaN        NaN      4,804        NaN       NaN        NaN
# 34       NaN        NaN        NaN     85,405        NaN       NaN        NaN
# 35       NaN        NaN        NaN        NaN        NaN       NaN        NaN
# 36       NaN        NaN        NaN     12,333        NaN       NaN        NaN
# 37       NaN        NaN          $     97,738        NaN       NaN        NaN
# 38       NaN    14.44 %        NaN        NaN        NaN       NaN    13.87 %
# 39    14,239        NaN        NaN        NaN          $    14,402        NaN
# 40       NaN    14.74 %        NaN        NaN        NaN       NaN    14.29 %
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11      2019 Unnamed: 12
# 0         NaN         NaN         NaN  Interest     Average
# 1         NaN     Average         NaN   Income/     Yield /
# 2         NaN     Balance         NaN   Expense     Rate(1)
# 3         NaN         NaN         NaN       NaN         NaN
# 4         NaN         NaN         NaN       NaN         NaN
# 5         NaN         NaN         NaN       NaN         NaN
# 6           $      12,320           $       258      2.09 %
# 7         NaN       5,464         NaN       127      2.32 %
# 8         NaN         NaN         NaN       NaN         NaN
# 9         NaN         NaN         NaN       NaN         NaN
# 10        NaN      85,334         NaN    18,384     21.54 %
# 11        NaN       1,963         NaN       182      9.27 %
# 12        NaN       1,306         NaN       137     10.49 %
# 13        NaN          46         NaN         2      4.35 %
# 14        NaN         NaN         NaN       NaN         NaN
# 15        NaN      88,649         NaN    18,705     21.10 %
# 16        NaN     106,433         NaN    19,090     17.94 %
# 17        NaN         NaN         NaN       NaN         NaN
# 18        NaN       1,327         NaN       NaN         NaN
# 19        NaN     (5,902)         NaN       NaN         NaN
# 20        NaN       3,819         NaN       NaN         NaN
# 21        NaN       (756)         NaN       NaN         NaN
# 22          $     105,677         NaN       NaN         NaN
# 23        NaN         NaN         NaN       NaN         NaN
# 24        NaN         NaN         NaN       NaN         NaN
# 25          $      64,756           $     1,566      2.42 %
# 26        NaN         NaN         NaN       NaN         NaN
# 27        NaN      11,941         NaN       358      3.00 %
# 28        NaN       9,310         NaN       367      3.94 %
# 29        NaN      86,007         NaN     2,291      2.66 %
# 30        NaN         NaN         NaN       NaN         NaN
# 31        NaN         280         NaN       NaN         NaN
# 32        NaN       4,473         NaN       NaN         NaN
# 33        NaN       4,753         NaN       NaN         NaN
# 34        NaN      90,760         NaN       NaN         NaN
# 35        NaN         NaN         NaN       NaN         NaN
# 36        NaN      14,917         NaN       NaN         NaN
# 37          $     105,677         NaN       NaN         NaN
# 38        NaN         NaN         NaN       NaN     15.28 %
# 39        NaN         NaN           $    16,799         NaN
# 40        NaN         NaN         NaN       NaN     15.78 %

# %%
 "x1": 7.65,
        "x2": 594.405,
        "y1": 111.3075,
        "y2": 506.0475,
        "width": 586.755,
        "height": 394.74

# %%
year_current="2022"
pdf_path=f"{os.getcwd()}/data/synchrony/synchrony_10K_{year_current}.pdf"
pdf_data=tabula.read_pdf(pdf_path, pages=35, stream=True)[0]

# %%
pdf_data_trans=pdf_data.transpose()
pdf_data_trans[0]=pdf_data_trans[0]+" "+ pdf_data_trans[1]
pdf_data_trans[4]=pdf_data_trans[4]+" "+ pdf_data_trans[5]
pdf_data_trans[7]=pdf_data_trans[7]+" "+ pdf_data_trans[8]
pdf_data_trans[13]=pdf_data_trans[13]+" "+ pdf_data_trans[14]
pdf_data_trans[25]=pdf_data_trans[25]+" "+ pdf_data_trans[26]
pdf_data=pdf_data_trans.drop(columns=[1,5,8,14,26]).transpose()

# %%
pdf_data.rename(columns={"Unnamed: 0":"position"})
# Out:
#                                              position Unnamed: 1
# 0             Years ended December 31 ($ in millions)        NaN  \
# 2                                              Assets        NaN
# 3                            Interest-earning assets:        NaN
# 4            Interest-earning cash and equivalents(2)        NaN
# 6                       Securities available for sale        NaN
# 7       Loan receivables, including held for sale(3):        NaN
# 9                                        Credit cards        NaN
# 10                         Consumer installment loans        NaN
# 11                         Commercial credit products        NaN
# 12                                              Other        NaN
# 13    Total loan receivables, including held for sale        NaN
# 15                      Total interest-earning assets        NaN
# 16                       Non-interest-earning assets:        NaN
# 17                            Cash and due from banks        NaN
# 18                        Allowance for credit losses        NaN
# 19                                       Other assets        NaN
# 20                  Total non-interest-earning assets        NaN
# 21                                       Total assets          $
# 22                                        Liabilities        NaN
# 23                      Interest-bearing liabilities:        NaN
# 24                  Interest-bearing deposit accounts          $
# 25  Borrowings of consolidated securitization enti...        NaN
# 27                             Senior unsecured notes        NaN
# 28                 Total interest-bearing liabilities        NaN
# 29                  Non-interest-bearing liabilities:        NaN
# 30              Non-interest-bearing deposit accounts        NaN
# 31                                  Other liabilities        NaN
# 32             Total non-interest-bearing liabilities        NaN
# 33                                  Total liabilities        NaN
# 34                                             Equity        NaN
# 35                                       Total equity        NaN
# 36                       Total liabilities and equity          $
# 37                            Interest rate spread(4)        NaN
# 38                                Net interest income        NaN
# 39                             Net interest margin(5)        NaN
#
#          Unnamed: 2 Unnamed: 3          Interest          Average Unnamed: 4
# 0   Average Balance        NaN  Income / Expense  Yield / Rate(1)        NaN  \
# 2               NaN        NaN               NaN              NaN        NaN
# 3               NaN        NaN               NaN              NaN        NaN
# 4               NaN        NaN               NaN              NaN        NaN
# 6             5,108        NaN                71           1.39 %        NaN
# 7               NaN        NaN               NaN              NaN        NaN
# 9            80,119        NaN            16,471          20.56 %        NaN
# 10            2,834        NaN               287          10.13 %        NaN
# 11            1,642        NaN               117           7.13 %        NaN
# 12               77        NaN                 6           7.79 %        NaN
# 13              NaN        NaN               NaN              NaN        NaN
# 15           99,995        NaN            17,146          17.15 %        NaN
# 16              NaN        NaN               NaN              NaN        NaN
# 17            1,472        NaN               NaN              NaN        NaN
# 18          (8,844)        NaN               NaN              NaN        NaN
# 19            5,529        NaN               NaN              NaN        NaN
# 20          (1,843)        NaN               NaN              NaN        NaN
# 21           98,152        NaN               NaN              NaN          $
# 22              NaN        NaN               NaN              NaN        NaN
# 23              NaN        NaN               NaN              NaN        NaN
# 24           65,624          $             1,008           1.54 %          $
# 25              NaN        NaN               NaN              NaN        NaN
# 27            7,315        NaN               317           4.33 %        NaN
# 28           79,407        NaN             1,521           1.92 %        NaN
# 29              NaN        NaN               NaN              NaN        NaN
# 30              382        NaN               NaN              NaN        NaN
# 31            4,991        NaN               NaN              NaN        NaN
# 32            5,373        NaN               NaN              NaN        NaN
# 33           84,780        NaN               NaN              NaN        NaN
# 34              NaN        NaN               NaN              NaN        NaN
# 35           13,372        NaN               NaN              NaN        NaN
# 36           98,152        NaN               NaN              NaN          $
# 37              NaN        NaN               NaN          15.23 %        NaN
# 38              NaN          $            15,625              NaN        NaN
# 39              NaN        NaN               NaN          15.63 %        NaN
#
#          Unnamed: 5 Unnamed: 6       Interest.1        Average.1 Unnamed: 7
# 0   Average Balance        NaN  Income/ Expense  Yield / Rate(1)        NaN  \
# 2               NaN        NaN              NaN              NaN        NaN
# 3               NaN        NaN              NaN              NaN        NaN
# 4               NaN        NaN              NaN              NaN        NaN
# 6             5,975        NaN               28           0.47 %        NaN
# 7               NaN        NaN              NaN              NaN        NaN
# 9            75,052        NaN           14,880          19.83 %        NaN
# 10            2,460        NaN              241           9.80 %        NaN
# 11            1,359        NaN              103           7.58 %        NaN
# 12               57        NaN                4           7.02 %        NaN
# 13              NaN        NaN              NaN              NaN        NaN
# 15           96,576        NaN           15,271          15.81 %        NaN
# 16              NaN        NaN              NaN              NaN        NaN
# 17            1,597        NaN              NaN              NaN        NaN
# 18          (9,402)        NaN              NaN              NaN        NaN
# 19            5,343        NaN              NaN              NaN        NaN
# 20          (2,462)        NaN              NaN              NaN        NaN
# 21           94,114        NaN              NaN              NaN          $
# 22              NaN        NaN              NaN              NaN        NaN
# 23              NaN        NaN              NaN              NaN        NaN
# 24           60,953          $              566           0.93 %          $
# 25              NaN        NaN              NaN              NaN        NaN
# 27            7,173        NaN              297           4.14 %        NaN
# 28           75,374        NaN            1,032           1.37 %        NaN
# 29              NaN        NaN              NaN              NaN        NaN
# 30              349        NaN              NaN              NaN        NaN
# 31            4,668        NaN              NaN              NaN        NaN
# 32            5,017        NaN              NaN              NaN        NaN
# 33           80,391        NaN              NaN              NaN        NaN
# 34              NaN        NaN              NaN              NaN        NaN
# 35           13,723        NaN              NaN              NaN        NaN
# 36           94,114        NaN              NaN              NaN          $
# 37              NaN        NaN              NaN          14.44 %        NaN
# 38              NaN          $           14,239              NaN        NaN
# 39              NaN        NaN              NaN          14.74 %        NaN
#
#          Unnamed: 8 Unnamed: 9       Interest.2        Average.2
# 0   Average Balance        NaN  Income/ Expense  Yield / Rate(1)
# 2               NaN        NaN              NaN              NaN
# 3               NaN        NaN              NaN              NaN
# 4               NaN        NaN              NaN              NaN
# 6             7,367        NaN               64           0.87 %
# 7               NaN        NaN              NaN              NaN
# 9            77,115        NaN           15,672          20.32 %
# 10            1,733        NaN              168           9.69 %
# 11            1,231        NaN              108           8.77 %
# 12               59        NaN                2           3.39 %
# 13              NaN        NaN              NaN              NaN
# 15          100,806        NaN           16,067          15.94 %
# 16              NaN        NaN              NaN              NaN
# 17            1,488        NaN              NaN              NaN
# 18          (9,488)        NaN              NaN              NaN
# 19            4,932        NaN              NaN              NaN
# 20          (3,068)        NaN              NaN              NaN
# 21           97,738        NaN              NaN              NaN
# 22              NaN        NaN              NaN              NaN
# 23              NaN        NaN              NaN              NaN
# 24           63,755          $            1,094           1.72 %
# 25              NaN        NaN              NaN              NaN
# 27            8,171        NaN              334           4.09 %
# 28           80,601        NaN            1,665           2.07 %
# 29              NaN        NaN              NaN              NaN
# 30              306        NaN              NaN              NaN
# 31            4,498        NaN              NaN              NaN
# 32            4,804        NaN              NaN              NaN
# 33           85,405        NaN              NaN              NaN
# 34              NaN        NaN              NaN              NaN
# 35           12,333        NaN              NaN              NaN
# 36           97,738        NaN              NaN              NaN
# 37              NaN        NaN              NaN          13.87 %
# 38              NaN          $           14,402              NaN
# 39              NaN        NaN              NaN          14.29 %

# %%
pdf_data=pdf_data.reset_index(drop=True)

# %%
pdf_data.rename(columns={"Unnamed: 0})
# Out:
#                                            Unnamed: 0 Unnamed: 1
# 0             Years ended December 31 ($ in millions)        NaN  \
# 2                                              Assets        NaN
# 3                            Interest-earning assets:        NaN
# 4            Interest-earning cash and equivalents(2)        NaN
# 6                       Securities available for sale        NaN
# 7       Loan receivables, including held for sale(3):        NaN
# 9                                        Credit cards        NaN
# 10                         Consumer installment loans        NaN
# 11                         Commercial credit products        NaN
# 12                                              Other        NaN
# 13    Total loan receivables, including held for sale        NaN
# 15                      Total interest-earning assets        NaN
# 16                       Non-interest-earning assets:        NaN
# 17                            Cash and due from banks        NaN
# 18                        Allowance for credit losses        NaN
# 19                                       Other assets        NaN
# 20                  Total non-interest-earning assets        NaN
# 21                                       Total assets          $
# 22                                        Liabilities        NaN
# 23                      Interest-bearing liabilities:        NaN
# 24                  Interest-bearing deposit accounts          $
# 25  Borrowings of consolidated securitization enti...        NaN
# 27                             Senior unsecured notes        NaN
# 28                 Total interest-bearing liabilities        NaN
# 29                  Non-interest-bearing liabilities:        NaN
# 30              Non-interest-bearing deposit accounts        NaN
# 31                                  Other liabilities        NaN
# 32             Total non-interest-bearing liabilities        NaN
# 33                                  Total liabilities        NaN
# 34                                             Equity        NaN
# 35                                       Total equity        NaN
# 36                       Total liabilities and equity          $
# 37                            Interest rate spread(4)        NaN
# 38                                Net interest income        NaN
# 39                             Net interest margin(5)        NaN
#
#          Unnamed: 2 Unnamed: 3          Interest          Average Unnamed: 4
# 0   Average Balance        NaN  Income / Expense  Yield / Rate(1)        NaN  \
# 2               NaN        NaN               NaN              NaN        NaN
# 3               NaN        NaN               NaN              NaN        NaN
# 4               NaN        NaN               NaN              NaN        NaN
# 6             5,108        NaN                71           1.39 %        NaN
# 7               NaN        NaN               NaN              NaN        NaN
# 9            80,119        NaN            16,471          20.56 %        NaN
# 10            2,834        NaN               287          10.13 %        NaN
# 11            1,642        NaN               117           7.13 %        NaN
# 12               77        NaN                 6           7.79 %        NaN
# 13              NaN        NaN               NaN              NaN        NaN
# 15           99,995        NaN            17,146          17.15 %        NaN
# 16              NaN        NaN               NaN              NaN        NaN
# 17            1,472        NaN               NaN              NaN        NaN
# 18          (8,844)        NaN               NaN              NaN        NaN
# 19            5,529        NaN               NaN              NaN        NaN
# 20          (1,843)        NaN               NaN              NaN        NaN
# 21           98,152        NaN               NaN              NaN          $
# 22              NaN        NaN               NaN              NaN        NaN
# 23              NaN        NaN               NaN              NaN        NaN
# 24           65,624          $             1,008           1.54 %          $
# 25              NaN        NaN               NaN              NaN        NaN
# 27            7,315        NaN               317           4.33 %        NaN
# 28           79,407        NaN             1,521           1.92 %        NaN
# 29              NaN        NaN               NaN              NaN        NaN
# 30              382        NaN               NaN              NaN        NaN
# 31            4,991        NaN               NaN              NaN        NaN
# 32            5,373        NaN               NaN              NaN        NaN
# 33           84,780        NaN               NaN              NaN        NaN
# 34              NaN        NaN               NaN              NaN        NaN
# 35           13,372        NaN               NaN              NaN        NaN
# 36           98,152        NaN               NaN              NaN          $
# 37              NaN        NaN               NaN          15.23 %        NaN
# 38              NaN          $            15,625              NaN        NaN
# 39              NaN        NaN               NaN          15.63 %        NaN
#
#          Unnamed: 5 Unnamed: 6       Interest.1        Average.1 Unnamed: 7
# 0   Average Balance        NaN  Income/ Expense  Yield / Rate(1)        NaN  \
# 2               NaN        NaN              NaN              NaN        NaN
# 3               NaN        NaN              NaN              NaN        NaN
# 4               NaN        NaN              NaN              NaN        NaN
# 6             5,975        NaN               28           0.47 %        NaN
# 7               NaN        NaN              NaN              NaN        NaN
# 9            75,052        NaN           14,880          19.83 %        NaN
# 10            2,460        NaN              241           9.80 %        NaN
# 11            1,359        NaN              103           7.58 %        NaN
# 12               57        NaN                4           7.02 %        NaN
# 13              NaN        NaN              NaN              NaN        NaN
# 15           96,576        NaN           15,271          15.81 %        NaN
# 16              NaN        NaN              NaN              NaN        NaN
# 17            1,597        NaN              NaN              NaN        NaN
# 18          (9,402)        NaN              NaN              NaN        NaN
# 19            5,343        NaN              NaN              NaN        NaN
# 20          (2,462)        NaN              NaN              NaN        NaN
# 21           94,114        NaN              NaN              NaN          $
# 22              NaN        NaN              NaN              NaN        NaN
# 23              NaN        NaN              NaN              NaN        NaN
# 24           60,953          $              566           0.93 %          $
# 25              NaN        NaN              NaN              NaN        NaN
# 27            7,173        NaN              297           4.14 %        NaN
# 28           75,374        NaN            1,032           1.37 %        NaN
# 29              NaN        NaN              NaN              NaN        NaN
# 30              349        NaN              NaN              NaN        NaN
# 31            4,668        NaN              NaN              NaN        NaN
# 32            5,017        NaN              NaN              NaN        NaN
# 33           80,391        NaN              NaN              NaN        NaN
# 34              NaN        NaN              NaN              NaN        NaN
# 35           13,723        NaN              NaN              NaN        NaN
# 36           94,114        NaN              NaN              NaN          $
# 37              NaN        NaN              NaN          14.44 %        NaN
# 38              NaN          $           14,239              NaN        NaN
# 39              NaN        NaN              NaN          14.74 %        NaN
#
#          Unnamed: 8 Unnamed: 9       Interest.2        Average.2
# 0   Average Balance        NaN  Income/ Expense  Yield / Rate(1)
# 2               NaN        NaN              NaN              NaN
# 3               NaN        NaN              NaN              NaN
# 4               NaN        NaN              NaN              NaN
# 6             7,367        NaN               64           0.87 %
# 7               NaN        NaN              NaN              NaN
# 9            77,115        NaN           15,672          20.32 %
# 10            1,733        NaN              168           9.69 %
# 11            1,231        NaN              108           8.77 %
# 12               59        NaN                2           3.39 %
# 13              NaN        NaN              NaN              NaN
# 15          100,806        NaN           16,067          15.94 %
# 16              NaN        NaN              NaN              NaN
# 17            1,488        NaN              NaN              NaN
# 18          (9,488)        NaN              NaN              NaN
# 19            4,932        NaN              NaN              NaN
# 20          (3,068)        NaN              NaN              NaN
# 21           97,738        NaN              NaN              NaN
# 22              NaN        NaN              NaN              NaN
# 23              NaN        NaN              NaN              NaN
# 24           63,755          $            1,094           1.72 %
# 25              NaN        NaN              NaN              NaN
# 27            8,171        NaN              334           4.09 %
# 28           80,601        NaN            1,665           2.07 %
# 29              NaN        NaN              NaN              NaN
# 30              306        NaN              NaN              NaN
# 31            4,498        NaN              NaN              NaN
# 32            4,804        NaN              NaN              NaN
# 33           85,405        NaN              NaN              NaN
# 34              NaN        NaN              NaN              NaN
# 35           12,333        NaN              NaN              NaN
# 36           97,738        NaN              NaN              NaN
# 37              NaN        NaN              NaN          13.87 %
# 38              NaN          $           14,402              NaN
# 39              NaN        NaN              NaN          14.29 %

# %%
import extract as ex

# %%
row_desc_ser=ex.extract_col_nm(pdf_data)
row_desc_ser.replace('', np.nan, inplace=True)
row_desc_ser=row_desc_ser.dropna()
row_desc_ser
# Out:
# Unnamed: 0    assets_interest_earning_assets
# dtype: object

# %%
# Delete the first two rows
pdf_data=pdf_data.drop([0,1]).reset_index(drop=True)
# Make the position column to index
pdf_data=pdf_data.rename(columns={"Unnamed: 0":"position"})
pdf_data["position"]=pdf_data["position"].apply(lambda x: x.split("(")[0])
#pdf_data["position"]=pdf_data["position"].apply(ex.replace_special_char)
#pdf_data["position"]=pdf_data["position"].apply(ex.snake_case)
pdf_data=pdf_data.set_index(keys="position",drop=True)
pdf_data
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# position
# Assets                                        NaN        NaN        NaN  \
# Interest-earning assets:                      NaN        NaN        NaN
# Interest-earning cash and                     NaN        NaN        NaN
# equivalents                                     $     10,215          $
# Securities available for sale                 NaN      5,108        NaN
# Loan receivables, including held for          NaN        NaN        NaN
# sale                                          NaN        NaN        NaN
# Credit cards                                  NaN     80,119        NaN
# Consumer installment loans                    NaN      2,834        NaN
# Commercial credit products                    NaN      1,642        NaN
# Other                                         NaN         77        NaN
# Total loan receivables, including             NaN        NaN        NaN
# held for sale                                 NaN     84,672        NaN
# Total interest-earning assets                 NaN     99,995        NaN
# Non-interest-earning assets:                  NaN        NaN        NaN
# Cash and due from banks                       NaN      1,472        NaN
# Allowance for credit losses                   NaN    (8,844)        NaN
# Other assets                                  NaN      5,529        NaN
# Total non-interest-earning assets             NaN    (1,843)        NaN
# Total assets                                    $     98,152        NaN
# Liabilities                                   NaN        NaN        NaN
# Interest-bearing liabilities:                 NaN        NaN        NaN
# Interest-bearing deposit accounts               $     65,624          $
# Borrowings of consolidated                    NaN        NaN        NaN
# securitization entities                       NaN      6,468        NaN
# Senior unsecured notes                        NaN      7,315        NaN
# Total interest-bearing liabilities            NaN     79,407        NaN
# Non-interest-bearing liabilities:             NaN        NaN        NaN
# Non-interest-bearing deposit accounts         NaN        382        NaN
# Other liabilities                             NaN      4,991        NaN
# Total non-interest-bearing liabilities        NaN      5,373        NaN
# Total liabilities                             NaN     84,780        NaN
# Equity                                        NaN        NaN        NaN
# Total equity                                  NaN     13,372        NaN
# Total liabilities and equity                    $     98,152        NaN
# Interest rate spread                          NaN        NaN        NaN
# Net interest income                           NaN        NaN          $
# Net interest margin                           NaN        NaN        NaN
#
#                                        Interest  Average Unnamed: 4
# position
# Assets                                      NaN      NaN        NaN  \
# Interest-earning assets:                    NaN      NaN        NaN
# Interest-earning cash and                   NaN      NaN        NaN
# equivalents                                 194   1.90 %          $
# Securities available for sale                71   1.39 %        NaN
# Loan receivables, including held for        NaN      NaN        NaN
# sale                                        NaN      NaN        NaN
# Credit cards                             16,471  20.56 %        NaN
# Consumer installment loans                  287  10.13 %        NaN
# Commercial credit products                  117   7.13 %        NaN
# Other                                         6   7.79 %        NaN
# Total loan receivables, including           NaN      NaN        NaN
# held for sale                            16,881  19.94 %        NaN
# Total interest-earning assets            17,146  17.15 %        NaN
# Non-interest-earning assets:                NaN      NaN        NaN
# Cash and due from banks                     NaN      NaN        NaN
# Allowance for credit losses                 NaN      NaN        NaN
# Other assets                                NaN      NaN        NaN
# Total non-interest-earning assets           NaN      NaN        NaN
# Total assets                                NaN      NaN          $
# Liabilities                                 NaN      NaN        NaN
# Interest-bearing liabilities:               NaN      NaN        NaN
# Interest-bearing deposit accounts         1,008   1.54 %          $
# Borrowings of consolidated                  NaN      NaN        NaN
# securitization entities                     196   3.03 %        NaN
# Senior unsecured notes                      317   4.33 %        NaN
# Total interest-bearing liabilities        1,521   1.92 %        NaN
# Non-interest-bearing liabilities:           NaN      NaN        NaN
# Non-interest-bearing deposit accounts       NaN      NaN        NaN
# Other liabilities                           NaN      NaN        NaN
# Total non-interest-bearing liabilities      NaN      NaN        NaN
# Total liabilities                           NaN      NaN        NaN
# Equity                                      NaN      NaN        NaN
# Total equity                                NaN      NaN        NaN
# Total liabilities and equity                NaN      NaN          $
# Interest rate spread                        NaN  15.23 %        NaN
# Net interest income                      15,625      NaN        NaN
# Net interest margin                         NaN  15.63 %        NaN
#
#                                        Unnamed: 5 Unnamed: 6 Interest.1
# position
# Assets                                        NaN        NaN        NaN  \
# Interest-earning assets:                      NaN        NaN        NaN
# Interest-earning cash and                     NaN        NaN        NaN
# equivalents                                11,673          $         15
# Securities available for sale               5,975        NaN         28
# Loan receivables, including held for          NaN        NaN        NaN
# sale                                          NaN        NaN        NaN
# Credit cards                               75,052        NaN     14,880
# Consumer installment loans                  2,460        NaN        241
# Commercial credit products                  1,359        NaN        103
# Other                                          57        NaN          4
# Total loan receivables, including             NaN        NaN        NaN
# held for sale                              78,928        NaN     15,228
# Total interest-earning assets              96,576        NaN     15,271
# Non-interest-earning assets:                  NaN        NaN        NaN
# Cash and due from banks                     1,597        NaN        NaN
# Allowance for credit losses               (9,402)        NaN        NaN
# Other assets                                5,343        NaN        NaN
# Total non-interest-earning assets         (2,462)        NaN        NaN
# Total assets                               94,114        NaN        NaN
# Liabilities                                   NaN        NaN        NaN
# Interest-bearing liabilities:                 NaN        NaN        NaN
# Interest-bearing deposit accounts          60,953          $        566
# Borrowings of consolidated                    NaN        NaN        NaN
# securitization entities                     7,248        NaN        169
# Senior unsecured notes                      7,173        NaN        297
# Total interest-bearing liabilities         75,374        NaN      1,032
# Non-interest-bearing liabilities:             NaN        NaN        NaN
# Non-interest-bearing deposit accounts         349        NaN        NaN
# Other liabilities                           4,668        NaN        NaN
# Total non-interest-bearing liabilities      5,017        NaN        NaN
# Total liabilities                          80,391        NaN        NaN
# Equity                                        NaN        NaN        NaN
# Total equity                               13,723        NaN        NaN
# Total liabilities and equity               94,114        NaN        NaN
# Interest rate spread                          NaN        NaN        NaN
# Net interest income                           NaN          $     14,239
# Net interest margin                           NaN        NaN        NaN
#
#                                        Average.1 Unnamed: 7 Unnamed: 8
# position
# Assets                                       NaN        NaN        NaN  \
# Interest-earning assets:                     NaN        NaN        NaN
# Interest-earning cash and                    NaN        NaN        NaN
# equivalents                               0.13 %          $     13,301
# Securities available for sale             0.47 %        NaN      7,367
# Loan receivables, including held for         NaN        NaN        NaN
# sale                                         NaN        NaN        NaN
# Credit cards                             19.83 %        NaN     77,115
# Consumer installment loans                9.80 %        NaN      1,733
# Commercial credit products                7.58 %        NaN      1,231
# Other                                     7.02 %        NaN         59
# Total loan receivables, including            NaN        NaN        NaN
# held for sale                            19.29 %        NaN     80,138
# Total interest-earning assets            15.81 %        NaN    100,806
# Non-interest-earning assets:                 NaN        NaN        NaN
# Cash and due from banks                      NaN        NaN      1,488
# Allowance for credit losses                  NaN        NaN    (9,488)
# Other assets                                 NaN        NaN      4,932
# Total non-interest-earning assets            NaN        NaN    (3,068)
# Total assets                                 NaN          $     97,738
# Liabilities                                  NaN        NaN        NaN
# Interest-bearing liabilities:                NaN        NaN        NaN
# Interest-bearing deposit accounts         0.93 %          $     63,755
# Borrowings of consolidated                   NaN        NaN        NaN
# securitization entities                   2.33 %        NaN      8,675
# Senior unsecured notes                    4.14 %        NaN      8,171
# Total interest-bearing liabilities        1.37 %        NaN     80,601
# Non-interest-bearing liabilities:            NaN        NaN        NaN
# Non-interest-bearing deposit accounts        NaN        NaN        306
# Other liabilities                            NaN        NaN      4,498
# Total non-interest-bearing liabilities       NaN        NaN      4,804
# Total liabilities                            NaN        NaN     85,405
# Equity                                       NaN        NaN        NaN
# Total equity                                 NaN        NaN     12,333
# Total liabilities and equity                 NaN          $     97,738
# Interest rate spread                     14.44 %        NaN        NaN
# Net interest income                          NaN        NaN        NaN
# Net interest margin                      14.74 %        NaN        NaN
#
#                                        Unnamed: 9 Interest.2 Average.2
# position
# Assets                                        NaN        NaN       NaN
# Interest-earning assets:                      NaN        NaN       NaN
# Interest-earning cash and                     NaN        NaN       NaN
# equivalents                                     $         53    0.40 %
# Securities available for sale                 NaN         64    0.87 %
# Loan receivables, including held for          NaN        NaN       NaN
# sale                                          NaN        NaN       NaN
# Credit cards                                  NaN     15,672   20.32 %
# Consumer installment loans                    NaN        168    9.69 %
# Commercial credit products                    NaN        108    8.77 %
# Other                                         NaN          2    3.39 %
# Total loan receivables, including             NaN        NaN       NaN
# held for sale                                 NaN     15,950   19.90 %
# Total interest-earning assets                 NaN     16,067   15.94 %
# Non-interest-earning assets:                  NaN        NaN       NaN
# Cash and due from banks                       NaN        NaN       NaN
# Allowance for credit losses                   NaN        NaN       NaN
# Other assets                                  NaN        NaN       NaN
# Total non-interest-earning assets             NaN        NaN       NaN
# Total assets                                  NaN        NaN       NaN
# Liabilities                                   NaN        NaN       NaN
# Interest-bearing liabilities:                 NaN        NaN       NaN
# Interest-bearing deposit accounts               $      1,094    1.72 %
# Borrowings of consolidated                    NaN        NaN       NaN
# securitization entities                       NaN        237    2.73 %
# Senior unsecured notes                        NaN        334    4.09 %
# Total interest-bearing liabilities            NaN      1,665    2.07 %
# Non-interest-bearing liabilities:             NaN        NaN       NaN
# Non-interest-bearing deposit accounts         NaN        NaN       NaN
# Other liabilities                             NaN        NaN       NaN
# Total non-interest-bearing liabilities        NaN        NaN       NaN
# Total liabilities                             NaN        NaN       NaN
# Equity                                        NaN        NaN       NaN
# Total equity                                  NaN        NaN       NaN
# Total liabilities and equity                  NaN        NaN       NaN
# Interest rate spread                          NaN        NaN   13.87 %
# Net interest income                             $     14,402       NaN
# Net interest margin                           NaN        NaN   14.29 %

# %%
ser_unit_cols=ex.find_unit_cols(pdf_data)
ser_unit_cols
# Out:
# Unnamed: 1    [$]
# Unnamed: 3    [$]
# Unnamed: 4    [$]
# Unnamed: 6    [$]
# Unnamed: 7    [$]
# Unnamed: 9    [$]
# dtype: object

# %%
# Remove unit columns
temp_df=pdf_data
li_col=list(temp_df.columns)
[li_col.remove(col) for col in ser_unit_cols.keys()]
print(li_col)
# Out:
# ['Unnamed: 2', 'Interest', 'Average', 'Unnamed: 5', 'Interest.1', 'Average.1', 'Unnamed: 8', 'Interest.2', 'Average.2']

# %%
li_new_col=[f"new_col_{str(li_col.index(col))}" for col in li_col]

# %%
for col in li_col:
    
    # get value and unit of the column
    col_val_unit=ex.get_val_unit(dataframe=temp_df,col_nm=col)

    # Add unit column whether we have unit in the unit column
    dict_check_unit=ex.check_unit(col_val_unit)
    
    if dict_check_unit["fg_unit"]:

        # get the index of the column
        idx_col=temp_df.columns.get_loc(col)

        if dict_check_unit["unit"]== "$":
            idx_col=idx_col
        elif dict_check_unit["unit"]== "%":
            idx_col=idx_col+1
        
        temp_df[col]=col_val_unit["val"]
        temp_df.insert(loc=idx_col, column=f'new_col: {col}', value=col_val_unit["unit"])

# %%
temp_df
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# position
# other                                         NaN         77        NaN  \
# total_loan_receivables_including              NaN        NaN        NaN
# held_for_sale                                 NaN     84,672        NaN
# total_interest_earning_assets                 NaN     99,995        NaN
# non_interest_earning_assets                   NaN        NaN        NaN
# cash_and_due_from_banks                       NaN      1,472        NaN
# allowance_for_credit_losses                   NaN    (8,844)        NaN
# other_assets                                  NaN      5,529        NaN
# total_non_interest_earning_assets             NaN    (1,843)        NaN
# total_assets                                    $     98,152        NaN
# liabilities                                   NaN        NaN        NaN
# interest_bearing_liabilities                  NaN        NaN        NaN
# interest_bearing_deposit_accounts               $     65,624          $
# borrowings_of_consolidated                    NaN        NaN        NaN
# securitization_entities                       NaN      6,468        NaN
# senior_unsecured_notes                        NaN      7,315        NaN
# total_interest_bearing_liabilities            NaN     79,407        NaN
# non_interest_bearing_liabilities              NaN        NaN        NaN
# non_interest_bearing_deposit_accounts         NaN        382        NaN
# other_liabilities                             NaN      4,991        NaN
# total_non_interest_bearing_liabilities        NaN      5,373        NaN
# total_liabilities                             NaN     84,780        NaN
# equity                                        NaN        NaN        NaN
# total_equity                                  NaN     13,372        NaN
# total_liabilities_and_equity                    $     98,152        NaN
# interest_rate_spread                          NaN        NaN        NaN
# net_interest_income                           NaN        NaN          $
# net_interest_margin                           NaN        NaN        NaN
#
#                                        Interest  Average Unnamed: 4
# position
# other                                         6   7.79 %        NaN  \
# total_loan_receivables_including            NaN      NaN        NaN
# held_for_sale                            16,881  19.94 %        NaN
# total_interest_earning_assets            17,146  17.15 %        NaN
# non_interest_earning_assets                 NaN      NaN        NaN
# cash_and_due_from_banks                     NaN      NaN        NaN
# allowance_for_credit_losses                 NaN      NaN        NaN
# other_assets                                NaN      NaN        NaN
# total_non_interest_earning_assets           NaN      NaN        NaN
# total_assets                                NaN      NaN          $
# liabilities                                 NaN      NaN        NaN
# interest_bearing_liabilities                NaN      NaN        NaN
# interest_bearing_deposit_accounts         1,008   1.54 %          $
# borrowings_of_consolidated                  NaN      NaN        NaN
# securitization_entities                     196   3.03 %        NaN
# senior_unsecured_notes                      317   4.33 %        NaN
# total_interest_bearing_liabilities        1,521   1.92 %        NaN
# non_interest_bearing_liabilities            NaN      NaN        NaN
# non_interest_bearing_deposit_accounts       NaN      NaN        NaN
# other_liabilities                           NaN      NaN        NaN
# total_non_interest_bearing_liabilities      NaN      NaN        NaN
# total_liabilities                           NaN      NaN        NaN
# equity                                      NaN      NaN        NaN
# total_equity                                NaN      NaN        NaN
# total_liabilities_and_equity                NaN      NaN          $
# interest_rate_spread                        NaN  15.23 %        NaN
# net_interest_income                      15,625      NaN        NaN
# net_interest_margin                         NaN  15.63 %        NaN
#
#                                        Unnamed: 5 Unnamed: 6 Interest.1
# position
# other                                          57        NaN          4  \
# total_loan_receivables_including              NaN        NaN        NaN
# held_for_sale                              78,928        NaN     15,228
# total_interest_earning_assets              96,576        NaN     15,271
# non_interest_earning_assets                   NaN        NaN        NaN
# cash_and_due_from_banks                     1,597        NaN        NaN
# allowance_for_credit_losses               (9,402)        NaN        NaN
# other_assets                                5,343        NaN        NaN
# total_non_interest_earning_assets         (2,462)        NaN        NaN
# total_assets                               94,114        NaN        NaN
# liabilities                                   NaN        NaN        NaN
# interest_bearing_liabilities                  NaN        NaN        NaN
# interest_bearing_deposit_accounts          60,953          $        566
# borrowings_of_consolidated                    NaN        NaN        NaN
# securitization_entities                     7,248        NaN        169
# senior_unsecured_notes                      7,173        NaN        297
# total_interest_bearing_liabilities         75,374        NaN      1,032
# non_interest_bearing_liabilities              NaN        NaN        NaN
# non_interest_bearing_deposit_accounts         349        NaN        NaN
# other_liabilities                           4,668        NaN        NaN
# total_non_interest_bearing_liabilities      5,017        NaN        NaN
# total_liabilities                          80,391        NaN        NaN
# equity                                        NaN        NaN        NaN
# total_equity                               13,723        NaN        NaN
# total_liabilities_and_equity               94,114        NaN        NaN
# interest_rate_spread                          NaN        NaN        NaN
# net_interest_income                           NaN          $     14,239
# net_interest_margin                           NaN        NaN        NaN
#
#                                        Average.1 Unnamed: 7 Unnamed: 8
# position
# other                                     7.02 %        NaN         59  \
# total_loan_receivables_including             NaN        NaN        NaN
# held_for_sale                            19.29 %        NaN     80,138
# total_interest_earning_assets            15.81 %        NaN    100,806
# non_interest_earning_assets                  NaN        NaN        NaN
# cash_and_due_from_banks                      NaN        NaN      1,488
# allowance_for_credit_losses                  NaN        NaN    (9,488)
# other_assets                                 NaN        NaN      4,932
# total_non_interest_earning_assets            NaN        NaN    (3,068)
# total_assets                                 NaN          $     97,738
# liabilities                                  NaN        NaN        NaN
# interest_bearing_liabilities                 NaN        NaN        NaN
# interest_bearing_deposit_accounts         0.93 %          $     63,755
# borrowings_of_consolidated                   NaN        NaN        NaN
# securitization_entities                   2.33 %        NaN      8,675
# senior_unsecured_notes                    4.14 %        NaN      8,171
# total_interest_bearing_liabilities        1.37 %        NaN     80,601
# non_interest_bearing_liabilities             NaN        NaN        NaN
# non_interest_bearing_deposit_accounts        NaN        NaN        306
# other_liabilities                            NaN        NaN      4,498
# total_non_interest_bearing_liabilities       NaN        NaN      4,804
# total_liabilities                            NaN        NaN     85,405
# equity                                       NaN        NaN        NaN
# total_equity                                 NaN        NaN     12,333
# total_liabilities_and_equity                 NaN          $     97,738
# interest_rate_spread                     14.44 %        NaN        NaN
# net_interest_income                          NaN        NaN        NaN
# net_interest_margin                      14.74 %        NaN        NaN
#
#                                        Unnamed: 9 Interest.2 Average.2
# position
# other                                         NaN          2    3.39 %
# total_loan_receivables_including              NaN        NaN       NaN
# held_for_sale                                 NaN     15,950   19.90 %
# total_interest_earning_assets                 NaN     16,067   15.94 %
# non_interest_earning_assets                   NaN        NaN       NaN
# cash_and_due_from_banks                       NaN        NaN       NaN
# allowance_for_credit_losses                   NaN        NaN       NaN
# other_assets                                  NaN        NaN       NaN
# total_non_interest_earning_assets             NaN        NaN       NaN
# total_assets                                  NaN        NaN       NaN
# liabilities                                   NaN        NaN       NaN
# interest_bearing_liabilities                  NaN        NaN       NaN
# interest_bearing_deposit_accounts               $      1,094    1.72 %
# borrowings_of_consolidated                    NaN        NaN       NaN
# securitization_entities                       NaN        237    2.73 %
# senior_unsecured_notes                        NaN        334    4.09 %
# total_interest_bearing_liabilities            NaN      1,665    2.07 %
# non_interest_bearing_liabilities              NaN        NaN       NaN
# non_interest_bearing_deposit_accounts         NaN        NaN       NaN
# other_liabilities                             NaN        NaN       NaN
# total_non_interest_bearing_liabilities        NaN        NaN       NaN
# total_liabilities                             NaN        NaN       NaN
# equity                                        NaN        NaN       NaN
# total_equity                                  NaN        NaN       NaN
# total_liabilities_and_equity                  NaN        NaN       NaN
# interest_rate_spread                          NaN        NaN   13.87 %
# net_interest_income                             $     14,402       NaN
# net_interest_margin                           NaN        NaN   14.29 %

# %%
ser_unit_cols=ex.find_unit_cols(temp_df)
ser_unit_cols
# Out:
# Unnamed: 1    [$]
# Unnamed: 3    [$]
# Unnamed: 4    [$]
# Unnamed: 6    [$]
# Unnamed: 7    [$]
# Unnamed: 9    [$]
# dtype: object

# %%
dict_unit={}

for col in ser_unit_cols.keys():
    idx=list(temp_df.columns).index(col)
    if ser_unit_cols[col][0]== "$":
        dict_unit[temp_df.columns[idx+1]]="$"
    elif ser_unit_cols[col][0]== "%":
        dict_unit[temp_df.columns[idx-1]]="%"


temp_df=temp_df.drop(columns=list(ser_unit_cols.keys()))
temp_df
# Out:
#                                        Unnamed: 2 Interest  Average
# position
# other                                          77        6   7.79 %  \
# total_loan_receivables_including              NaN      NaN      NaN
# held_for_sale                              84,672   16,881  19.94 %
# total_interest_earning_assets              99,995   17,146  17.15 %
# non_interest_earning_assets                   NaN      NaN      NaN
# cash_and_due_from_banks                     1,472      NaN      NaN
# allowance_for_credit_losses               (8,844)      NaN      NaN
# other_assets                                5,529      NaN      NaN
# total_non_interest_earning_assets         (1,843)      NaN      NaN
# total_assets                               98,152      NaN      NaN
# liabilities                                   NaN      NaN      NaN
# interest_bearing_liabilities                  NaN      NaN      NaN
# interest_bearing_deposit_accounts          65,624    1,008   1.54 %
# borrowings_of_consolidated                    NaN      NaN      NaN
# securitization_entities                     6,468      196   3.03 %
# senior_unsecured_notes                      7,315      317   4.33 %
# total_interest_bearing_liabilities         79,407    1,521   1.92 %
# non_interest_bearing_liabilities              NaN      NaN      NaN
# non_interest_bearing_deposit_accounts         382      NaN      NaN
# other_liabilities                           4,991      NaN      NaN
# total_non_interest_bearing_liabilities      5,373      NaN      NaN
# total_liabilities                          84,780      NaN      NaN
# equity                                        NaN      NaN      NaN
# total_equity                               13,372      NaN      NaN
# total_liabilities_and_equity               98,152      NaN      NaN
# interest_rate_spread                          NaN      NaN  15.23 %
# net_interest_income                           NaN   15,625      NaN
# net_interest_margin                           NaN      NaN  15.63 %
#
#                                        Unnamed: 5 Interest.1 Average.1
# position
# other                                          57          4    7.02 %  \
# total_loan_receivables_including              NaN        NaN       NaN
# held_for_sale                              78,928     15,228   19.29 %
# total_interest_earning_assets              96,576     15,271   15.81 %
# non_interest_earning_assets                   NaN        NaN       NaN
# cash_and_due_from_banks                     1,597        NaN       NaN
# allowance_for_credit_losses               (9,402)        NaN       NaN
# other_assets                                5,343        NaN       NaN
# total_non_interest_earning_assets         (2,462)        NaN       NaN
# total_assets                               94,114        NaN       NaN
# liabilities                                   NaN        NaN       NaN
# interest_bearing_liabilities                  NaN        NaN       NaN
# interest_bearing_deposit_accounts          60,953        566    0.93 %
# borrowings_of_consolidated                    NaN        NaN       NaN
# securitization_entities                     7,248        169    2.33 %
# senior_unsecured_notes                      7,173        297    4.14 %
# total_interest_bearing_liabilities         75,374      1,032    1.37 %
# non_interest_bearing_liabilities              NaN        NaN       NaN
# non_interest_bearing_deposit_accounts         349        NaN       NaN
# other_liabilities                           4,668        NaN       NaN
# total_non_interest_bearing_liabilities      5,017        NaN       NaN
# total_liabilities                          80,391        NaN       NaN
# equity                                        NaN        NaN       NaN
# total_equity                               13,723        NaN       NaN
# total_liabilities_and_equity               94,114        NaN       NaN
# interest_rate_spread                          NaN        NaN   14.44 %
# net_interest_income                           NaN     14,239       NaN
# net_interest_margin                           NaN        NaN   14.74 %
#
#                                        Unnamed: 8 Interest.2 Average.2
# position
# other                                          59          2    3.39 %
# total_loan_receivables_including              NaN        NaN       NaN
# held_for_sale                              80,138     15,950   19.90 %
# total_interest_earning_assets             100,806     16,067   15.94 %
# non_interest_earning_assets                   NaN        NaN       NaN
# cash_and_due_from_banks                     1,488        NaN       NaN
# allowance_for_credit_losses               (9,488)        NaN       NaN
# other_assets                                4,932        NaN       NaN
# total_non_interest_earning_assets         (3,068)        NaN       NaN
# total_assets                               97,738        NaN       NaN
# liabilities                                   NaN        NaN       NaN
# interest_bearing_liabilities                  NaN        NaN       NaN
# interest_bearing_deposit_accounts          63,755      1,094    1.72 %
# borrowings_of_consolidated                    NaN        NaN       NaN
# securitization_entities                     8,675        237    2.73 %
# senior_unsecured_notes                      8,171        334    4.09 %
# total_interest_bearing_liabilities         80,601      1,665    2.07 %
# non_interest_bearing_liabilities              NaN        NaN       NaN
# non_interest_bearing_deposit_accounts         306        NaN       NaN
# other_liabilities                           4,498        NaN       NaN
# total_non_interest_bearing_liabilities      4,804        NaN       NaN
# total_liabilities                          85,405        NaN       NaN
# equity                                        NaN        NaN       NaN
# total_equity                               12,333        NaN       NaN
# total_liabilities_and_equity               97,738        NaN       NaN
# interest_rate_spread                          NaN        NaN   13.87 %
# net_interest_income                           NaN     14,402       NaN
# net_interest_margin                           NaN        NaN   14.29 %

# %%
temp_df=temp_df.dropna(how="all")

# %%
temp_df
# Out:
#                                        Unnamed: 2 Interest  Average
# position
# other                                          77        6   7.79 %  \
# held_for_sale                              84,672   16,881  19.94 %
# total_interest_earning_assets              99,995   17,146  17.15 %
# cash_and_due_from_banks                     1,472      NaN      NaN
# allowance_for_credit_losses               (8,844)      NaN      NaN
# other_assets                                5,529      NaN      NaN
# total_non_interest_earning_assets         (1,843)      NaN      NaN
# total_assets                               98,152      NaN      NaN
# interest_bearing_deposit_accounts          65,624    1,008   1.54 %
# securitization_entities                     6,468      196   3.03 %
# senior_unsecured_notes                      7,315      317   4.33 %
# total_interest_bearing_liabilities         79,407    1,521   1.92 %
# non_interest_bearing_deposit_accounts         382      NaN      NaN
# other_liabilities                           4,991      NaN      NaN
# total_non_interest_bearing_liabilities      5,373      NaN      NaN
# total_liabilities                          84,780      NaN      NaN
# total_equity                               13,372      NaN      NaN
# total_liabilities_and_equity               98,152      NaN      NaN
# interest_rate_spread                          NaN      NaN  15.23 %
# net_interest_income                           NaN   15,625      NaN
# net_interest_margin                           NaN      NaN  15.63 %
#
#                                        Unnamed: 5 Interest.1 Average.1
# position
# other                                          57          4    7.02 %  \
# held_for_sale                              78,928     15,228   19.29 %
# total_interest_earning_assets              96,576     15,271   15.81 %
# cash_and_due_from_banks                     1,597        NaN       NaN
# allowance_for_credit_losses               (9,402)        NaN       NaN
# other_assets                                5,343        NaN       NaN
# total_non_interest_earning_assets         (2,462)        NaN       NaN
# total_assets                               94,114        NaN       NaN
# interest_bearing_deposit_accounts          60,953        566    0.93 %
# securitization_entities                     7,248        169    2.33 %
# senior_unsecured_notes                      7,173        297    4.14 %
# total_interest_bearing_liabilities         75,374      1,032    1.37 %
# non_interest_bearing_deposit_accounts         349        NaN       NaN
# other_liabilities                           4,668        NaN       NaN
# total_non_interest_bearing_liabilities      5,017        NaN       NaN
# total_liabilities                          80,391        NaN       NaN
# total_equity                               13,723        NaN       NaN
# total_liabilities_and_equity               94,114        NaN       NaN
# interest_rate_spread                          NaN        NaN   14.44 %
# net_interest_income                           NaN     14,239       NaN
# net_interest_margin                           NaN        NaN   14.74 %
#
#                                        Unnamed: 8 Interest.2 Average.2
# position
# other                                          59          2    3.39 %
# held_for_sale                              80,138     15,950   19.90 %
# total_interest_earning_assets             100,806     16,067   15.94 %
# cash_and_due_from_banks                     1,488        NaN       NaN
# allowance_for_credit_losses               (9,488)        NaN       NaN
# other_assets                                4,932        NaN       NaN
# total_non_interest_earning_assets         (3,068)        NaN       NaN
# total_assets                               97,738        NaN       NaN
# interest_bearing_deposit_accounts          63,755      1,094    1.72 %
# securitization_entities                     8,675        237    2.73 %
# senior_unsecured_notes                      8,171        334    4.09 %
# total_interest_bearing_liabilities         80,601      1,665    2.07 %
# non_interest_bearing_deposit_accounts         306        NaN       NaN
# other_liabilities                           4,498        NaN       NaN
# total_non_interest_bearing_liabilities      4,804        NaN       NaN
# total_liabilities                          85,405        NaN       NaN
# total_equity                               12,333        NaN       NaN
# total_liabilities_and_equity               97,738        NaN       NaN
# interest_rate_spread                          NaN        NaN   13.87 %
# net_interest_income                           NaN     14,402       NaN
# net_interest_margin                           NaN        NaN   14.29 %

# %%
li_dict_df=ex.separate_df(temp_df,3)

# %%
li_dict_df=[
    dict(
        year=dict_df["year"],
        df=dict_df["df"].rename(
            columns=ex.assign_col_nms_from_desc(
                dict_df["df"],
                row_desc_ser
            )
        )
    )

    for dict_df in li_dict_df
]

# %%
li_dict_df
# Out:
# [{'year': None,
#   'df':                                        Unnamed: 2 Interest  Average
#   position
#   other                                          77        6   7.79 %
#   held_for_sale                              84,672   16,881  19.94 %
#   total_interest_earning_assets              99,995   17,146  17.15 %
#   cash_and_due_from_banks                     1,472      NaN      NaN
#   allowance_for_credit_losses               (8,844)      NaN      NaN
#   other_assets                                5,529      NaN      NaN
#   total_non_interest_earning_assets         (1,843)      NaN      NaN
#   total_assets                               98,152      NaN      NaN
#   interest_bearing_deposit_accounts          65,624    1,008   1.54 %
#   securitization_entities                     6,468      196   3.03 %
#   senior_unsecured_notes                      7,315      317   4.33 %
#   total_interest_bearing_liabilities         79,407    1,521   1.92 %
#   non_interest_bearing_deposit_accounts         382      NaN      NaN
#   other_liabilities                           4,991      NaN      NaN
#   total_non_interest_bearing_liabilities      5,373      NaN      NaN
#   total_liabilities                          84,780      NaN      NaN
#   total_equity                               13,372      NaN      NaN
#   total_liabilities_and_equity               98,152      NaN      NaN
#   interest_rate_spread                          NaN      NaN  15.23 %
#   net_interest_income                           NaN   15,625      NaN
#   net_interest_margin                           NaN      NaN  15.63 %},
#  {'year': None,
#   'df':                                        Unnamed: 5 Interest.1 Average.1
#   position
#   other                                          57          4    7.02 %
#   held_for_sale                              78,928     15,228   19.29 %
#   total_interest_earning_assets              96,576     15,271   15.81 %
#   cash_and_due_from_banks                     1,597        NaN       NaN
#   allowance_for_credit_losses               (9,402)        NaN       NaN
#   other_assets                                5,343        NaN       NaN
#   total_non_interest_earning_assets         (2,462)        NaN       NaN
#   total_assets                               94,114        NaN       NaN
#   interest_bearing_deposit_accounts          60,953        566    0.93 %
#   securitization_entities                     7,248        169    2.33 %
#   senior_unsecured_notes                      7,173        297    4.14 %
#   total_interest_bearing_liabilities         75,374      1,032    1.37 %
#   non_interest_bearing_deposit_accounts         349        NaN       NaN
#   other_liabilities                           4,668        NaN       NaN
#   total_non_interest_bearing_liabilities      5,017        NaN       NaN
#   total_liabilities                          80,391        NaN       NaN
#   total_equity                               13,723        NaN       NaN
#   total_liabilities_and_equity               94,114        NaN       NaN
#   interest_rate_spread                          NaN        NaN   14.44 %
#   net_interest_income                           NaN     14,239       NaN
#   net_interest_margin                           NaN        NaN   14.74 %},
#  {'year': None,
#   'df':                                        Unnamed: 8 Interest.2 Average.2
#   position
#   other                                          59          2    3.39 %
#   held_for_sale                              80,138     15,950   19.90 %
#   total_interest_earning_assets             100,806     16,067   15.94 %
#   cash_and_due_from_banks                     1,488        NaN       NaN
#   allowance_for_credit_losses               (9,488)        NaN       NaN
#   other_assets                                4,932        NaN       NaN
#   total_non_interest_earning_assets         (3,068)        NaN       NaN
#   total_assets                               97,738        NaN       NaN
#   interest_bearing_deposit_accounts          63,755      1,094    1.72 %
#   securitization_entities                     8,675        237    2.73 %
#   senior_unsecured_notes                      8,171        334    4.09 %
#   total_interest_bearing_liabilities         80,601      1,665    2.07 %
#   non_interest_bearing_deposit_accounts         306        NaN       NaN
#   other_liabilities                           4,498        NaN       NaN
#   total_non_interest_bearing_liabilities      4,804        NaN       NaN
#   total_liabilities                          85,405        NaN       NaN
#   total_equity                               12,333        NaN       NaN
#   total_liabilities_and_equity               97,738        NaN       NaN
#   interest_rate_spread                          NaN        NaN   13.87 %
#   net_interest_income                           NaN     14,402       NaN
#   net_interest_margin                           NaN        NaN   14.29 %}]
